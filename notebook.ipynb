# %% [markdown]
# # Part 2: CNN Computer Vision
#
# This notebook summarizes the manufacturing defect classification prototype.

# %% [markdown]
# ## Submission outputs
#
# - `results/accuracy_loss_curves.png`
# - `results/confusion_matrix.png`
# - `sample_predictions/prediction_outputs.png`

# %%
from pathlib import Path
import pandas as pd

source_root = Path('..') / 'part_2_cnn_computer_vision' / 'outputs'
history = pd.read_csv(source_root / 'training_history.csv')
history

# %%
import json

summary = json.loads((source_root / 'results_summary.json').read_text())
summary
